# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv("https://github.com/YBI-Foundation/Dataset/raw/main/Movies%20Recommendation.csv")

# %%
movies
# Out:
#       Movie_ID                  Movie_Title                       Movie_Genre  \
# 0            1                   Four Rooms                      Crime Comedy
# 1            2                    Star Wars  Adventure Action Science Fiction
# 2            3                 Finding Nemo                  Animation Family
# 3            4                 Forrest Gump              Comedy Drama Romance
# 4            5              American Beauty                             Drama
# ...        ...                          ...                               ...
# 4755      4784             Midnight Cabaret                            Horror
# 4756      4785             Growing Up Smith               Comedy Family Drama
# 4757      4786                       8 Days                    Thriller Drama
# 4758      4787              Running Forever                            Family
# 4759      4788  To Be Frank, Sinatra at 100                       Documentary
#
# ...

# %%
movies.head()
# Out:
#    Movie_ID      Movie_Title                       Movie_Genre Movie_Language  \
# 0         1       Four Rooms                      Crime Comedy             en
# 1         2        Star Wars  Adventure Action Science Fiction             en
# 2         3     Finding Nemo                  Animation Family             en
# 3         4     Forrest Gump              Comedy Drama Romance             en
# 4         5  American Beauty                             Drama             en
#
#    Movie_Budget  Movie_Popularity Movie_Release_Date  Movie_Revenue  \
# 0       4000000         22.876230         09-12-1995        4300000
# 1      11000000        126.393695         25-05-1977      775398007
# 2      94000000         85.688789         30-05-2003      940335536
# 3      55000000        138.133331         06-07-1994      677945399
# 4      15000000         80.878605         15-09-1999      356296601
#
#    Movie_Runtime  Movie_Vote  ...  \
# 0           98.0         6.5  ...
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4760 entries, 0 to 4759
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Movie_ID                  4760 non-null   int64
#  1   Movie_Title               4760 non-null   object
#  2   Movie_Genre               4760 non-null   object
#  3   Movie_Language            4760 non-null   object
#  4   Movie_Budget              4760 non-null   int64
#  5   Movie_Popularity          4760 non-null   float64
#  6   Movie_Release_Date        4760 non-null   object
#  7   Movie_Revenue             4760 non-null   int64
#  8   Movie_Runtime             4758 non-null   float64
#  9   Movie_Vote                4760 non-null   float64
#  10  Movie_Vote_Count          4760 non-null   int64
#  11  Movie_Homepage            1699 non-null   object
#  12  Movie_Keywords            4373 non-null   object
# ...

# %%
movies.shape
# Out:
# (4760, 21)

# %%
movies.columns
# Out:
# Index(['Movie_ID', 'Movie_Title', 'Movie_Genre', 'Movie_Language',
#        'Movie_Budget', 'Movie_Popularity', 'Movie_Release_Date',
#        'Movie_Revenue', 'Movie_Runtime', 'Movie_Vote', 'Movie_Vote_Count',
#        'Movie_Homepage', 'Movie_Keywords', 'Movie_Overview',
#        'Movie_Production_House', 'Movie_Production_Country',
#        'Movie_Spoken_Language', 'Movie_Tagline', 'Movie_Cast', 'Movie_Crew',
#        'Movie_Director'],
#       dtype='object')

# %%
#Feature selection

# %%
movie_features =movies[['Movie_Director', 'Movie_Title', 'Movie_Genre', 'Movie_Language',
       'Movie_Crew']].fillna('')

# %%
 movie_features.shape
# Out:
# (4760, 5)

# %%
  movie_features
# Out:
#          Movie_Director                  Movie_Title  \
# 0        Allison Anders                   Four Rooms
# 1          George Lucas                    Star Wars
# 2        Andrew Stanton                 Finding Nemo
# 3       Robert Zemeckis                 Forrest Gump
# 4            Sam Mendes              American Beauty
# ...                 ...                          ...
# 4755         Pece Dingo             Midnight Cabaret
# 4756       Frank Lotito             Growing Up Smith
# 4757       Jaco Booyens                       8 Days
# 4758                                 Running Forever
# 4759  Simon Napier-Bell  To Be Frank, Sinatra at 100
#
#                            Movie_Genre Movie_Language  \
# 0                         Crime Comedy             en
# 1     Adventure Action Science Fiction             en
# 2                     Animation Family             en
# 3                 Comedy Drama Romance             en
# ...

# %%
x = movie_features['Movie_Director'] +'' + movie_features['Movie_Title'] + '' + movie_features['Movie_Genre'] + '' + movie_features['Movie_Language'] + '' + movie_features['Movie_Crew']

# %%
x
# Out:
# 0       Allison AndersFour RoomsCrime Comedyen[{'name'...
# 1       George LucasStar WarsAdventure Action Science ...
# 2       Andrew StantonFinding NemoAnimation Familyen[{...
# 3       Robert ZemeckisForrest GumpComedy Drama Romanc...
# 4       Sam MendesAmerican BeautyDramaen[{'name': 'Tho...
#                               ...
# 4755    Pece DingoMidnight CabaretHorroren[{'name': 'P...
# 4756    Frank LotitoGrowing Up SmithComedy Family Dram...
# 4757    Jaco Booyens8 DaysThriller Dramaen[{'name': 'J...
# 4758                            Running ForeverFamilyen[]
# 4759    Simon Napier-BellTo Be Frank, Sinatra at 100Do...
# Length: 4760, dtype: object

# %%
x.shape
# Out:
# (4760,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer()

# %%
X = tfidf.fit_transform(x)

# %%
X.shape
# Out:
# (4760, 223713)

# %%
print(X)
# Out:
#   (0, 36532)	0.031765471921838456
#   (0, 172242)	0.031765471921838456
#   (0, 218355)	0.018597520446990482
#   (0, 217551)	0.018597520446990482
#   (0, 219713)	0.031765471921838456
#   (0, 199724)	0.01572604961287008
#   (0, 36531)	0.031765471921838456
#   (0, 172233)	0.031765471921838456
#   (0, 194066)	0.010427912593582112
#   (0, 195356)	0.030297700538874463
#   (0, 190256)	0.007314010125932308
#   (0, 36523)	0.031765471921838456
#   (0, 172205)	0.031765471921838456
#   (0, 181265)	0.014272671766339548
#   (0, 197618)	0.026320757403610964
#   (0, 190416)	0.014103615227181699
#   (0, 36522)	0.031765471921838456
#   (0, 172202)	0.031765471921838456
#   (0, 194736)	0.010353882004479245
#   (0, 216244)	0.011105906009735713
#   (0, 36521)	0.031765471921838456
#   (0, 172201)	0.031765471921838456
#   (0, 192477)	0.014360255949364218
#   (0, 190539)	0.031765471921838456
#   (0, 205283)	0.02381158565131147
#   :	:
#   (4757, 191199)	0.02564057473328167
# ...

# %%
# cosine Similaarity

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_score = cosine_similarity(X)

# %%
similarity_score
# Out:
# array([[1.        , 0.50382483, 0.64918558, ..., 0.15338951, 0.        ,
#         0.07192988],
#        [0.50382483, 1.        , 0.51062074, ..., 0.11590202, 0.        ,
#         0.05394985],
#        [0.64918558, 0.51062074, 1.        , ..., 0.14433778, 0.        ,
#         0.07075992],
#        ...,
#        [0.15338951, 0.11590202, 0.14433778, ..., 1.        , 0.        ,
#         0.01860095],
#        [0.        , 0.        , 0.        , ..., 0.        , 1.        ,
#         0.        ],
#        [0.07192988, 0.05394985, 0.07075992, ..., 0.01860095, 0.        ,
#         1.        ]])

# %%
similarity_score.shape
# Out:
# (4760, 4760)

# %%
# Movie Name as Imput from User

# %%
Movie_Name = input('Enter a movie name: ')
# Out:
# Enter a movie name: avatar

# %%
All_Movies_Title_List = df['Movie_Title'].tolist()

# %%
import difflib

# %%
Movie_Recommendation = difflib.get_close_matches(Movie_Name,All_Movies_Title_List)
print(Movie_Recommendation)
# Out:
# ['Avatar']

# %%
Close_Match = Movie_Recommendation[0]
print(Close_Match)
# Out:
# Avatar

# %%
Index_of_Movie = movies[movies.Movie_Title == Close_Match]['Movie_ID'].values[0]
print(Index_of_Movie)
# Out:
# 2692

# %%
#getting a list of similar movies

# %%
Score = list(enumerate(similarity_score[Index_of_Movie]))
print(Score)
# Out:
# [(0, 0.5331790392573692), (1, 0.40491217424745674), (2, 0.506112612137234), (3, 0.5648284180293732), (4, 0.5640004624752463), (5, 0.47988821675551696), (6, 0.5683074291378608), (7, 0.33263417171548526), (8, 0.3308650949175555), (9, 0.5657655807795732), (10, 0.5785377837817043), (11, 0.3021233048566026), (12, 0.4754927677613022), (13, 0.4938624594441074), (14, 0.45702018669438405), (15, 0.36063391602312767), (16, 0.43217944779397854), (17, 0.403081399282801), (18, 0.4542464272425352), (19, 0.3420523851512552), (20, 0.5486209424157654), (21, 0.362758906222585), (22, 0.43742780908033574), (23, 0.5369191398534803), (24, 0.5361324635072124), (25, 0.3611204416252457), (26, 0.5466984553131825), (27, 0.5853810836749129), (28, 0.4183360601222503), (29, 0.310664002309158), (30, 0.39133515604226143), (31, 0.459120927826806), (32, 0.3154471651555395), (33, 0.2876163877719254), (34, 0.3633910497295987), (35, 0.499598825286519), (36, 0.4364258242276653), (37, 0.49586204799205374), (38, 0.339864004
# ...

# %%
len(Score)
# Out:
# 4760
